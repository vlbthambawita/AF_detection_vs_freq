# %%
# %run train.py \
  --data_path ptbxl/500hz \
  --model cnn_lstm
# Out:
# ...
# ECG K-FOLD TRAINING
# ...
# Device        : cpu
# Dataset       : ptbxl
# Sampling rate : 500 Hz
# Model         : cnn_lstm
# ...
#
# === Fold 1/5 ===
# Train       : total=1916 | Normal=958 (50.00%) | AFIB=958 (50.00%)
# Validation  : total=476 | Normal=238 (50.00%) | AFIB=238 (50.00%)
#
# Epoch 01/50 | TrainLoss 0.3028 | ValLoss 0.2741 | ACC 87.82% | F1 0.8632 | Time 29.67s
# Epoch 02/50 | TrainLoss 0.1454 | ValLoss 0.1839 | ACC 94.33% | F1 0.9412 | Time 29.33s
# Epoch 03/50 | TrainLoss 0.0942 | ValLoss 0.1832 | ACC 89.50% | F1 0.8826 | Time 29.30s
# Epoch 04/50 | TrainLoss 0.0873 | ValLoss 0.1303 | ACC 95.38% | F1 0.9528 | Time 29.22s
# Epoch 05/50 | TrainLoss 0.0754 | ValLoss 0.0990 | ACC 97.06% | F1 0.9703 | Time 28.34s
# Epoch 06/50 | TrainLoss 0.0746 | ValLoss 0.1365 | ACC 97.27% | F1 0.9731 | Time 28.25s
# Epoch 07/50 | TrainLoss 0.0653 | ValLoss 0.0933 | ACC 96.64% | F1 0.9654 | Time 29.12s
# Epoch 08/50 | TrainLoss 0.0622 | ValLoss 0.0793 | ACC 98.11% | F1 0.9811 | Time 28.01s
# ...
